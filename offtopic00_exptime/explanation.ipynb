# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

ts = np.linspace(1, 1000, 1000)
accuracyA = 1 - 2**(-ts)
accuracyB = 1 - 1.5**(-ts)
accuracyC = 1 - 1.1**(-ts)
plt.semilogx(ts, accuracyA)
plt.semilogx(ts, accuracyB)
plt.semilogx(ts, accuracyC)
plt.show()

# %%
error = 1 - accuracy
plt.loglog(ts, error)
plt.show()
